# %% [markdown]
# # Webscraping for the Glassnode Endpoints

# %% [markdown]
# Glassnode offers a variety of metrics for on-chain analysis, each with it's own unique endpoint. Here I am webscraping the API homepage to create a list of all of the endpoints available for my API call.

# %%
# Importing necessary libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# The individual endpoints are organized by category, here I am creating a list of each of the category URL's prior to webscraping.

# %%
url_list = [
            "https://docs.glassnode.com/api/addresses",
            "https://docs.glassnode.com/api/blockchain",
            "https://docs.glassnode.com/api/derivatives", "https://docs.glassnode.com/api/distribution",
            "https://docs.glassnode.com/api/entities", "https://docs.glassnode.com/api/fees",
            "https://docs.glassnode.com/api/indicators", "https://docs.glassnode.com/api/institutions",
            "https://docs.glassnode.com/api/market", "https://docs.glassnode.com/api/mining",
            "https://docs.glassnode.com/api/protocols", "https://docs.glassnode.com/api/defi",
            "https://docs.glassnode.com/api/supply", "https://docs.glassnode.com/api/transactions"]

# %% [markdown]
# Here I am using a list comprehension to webscrape the category URL's specified above and creating a new list that includes all of the endpoints that Glassnode has available.

# %%
urls = []

for url in url_list:
    headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'}
    page = url
    pageTree = requests.get(page, headers=headers)
    pageSoup = BeautifulSoup(pageTree.content)
    string = "https://api.glassnode.com"
    alpha = pageSoup.find_all('span',{"class":"text-4505230f--TextH400-3033861f--textContentFamily-49a318e1--apiMethodPathPath-3e6eb619"})
    
    for a in list(range(len(alpha))):
        urls.append(string + str(alpha[a]).split('">')[1].split("</span>")[0])

# %%
urls
# Out:
# ['https://api.glassnode.com/v1/metrics/addresses/sending_to_exchanges_count',
#  'https://api.glassnode.com/v1/metrics/addresses/receiving_from_exchanges_count',
#  'https://api.glassnode.com/v1/metrics/addresses/count',
#  'https://api.glassnode.com/v1/metrics/addresses/sending_count',
#  'https://api.glassnode.com/v1/metrics/addresses/receiving_count',
#  'https://api.glassnode.com/v1/metrics/addresses/active_count',
#  'https://api.glassnode.com/v1/metrics/addresses/new_non_zero_count',
#  'https://api.glassnode.com/v1/metrics/addresses/accumulation_count',
#  'https://api.glassnode.com/v1/metrics/addresses/accumulation_balance',
#  'https://api.glassnode.com/v1/metrics/addresses/non_zero_count',
#  'https://api.glassnode.com/v1/metrics/addresses/min_point_zero_1_count',
#  'https://api.glassnode.com/v1/metrics/addresses/min_point_1_count',
#  'https://api.glassnode.com/v1/metrics/addresses/min_1_count',
#  'https://api.glassnode.com/v1/metrics/addresses/min_10_count',
# ...

# %%
urls = pd.DataFrame(urls)

# %%
type(urls)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# After converting the list of endpoints into a Panda's DataFrame, I saved it down as an Excel file in case it needs to be accessed later on.

# %%
urls.to_excel("glassnode_api_urls_v3.xlsx")
