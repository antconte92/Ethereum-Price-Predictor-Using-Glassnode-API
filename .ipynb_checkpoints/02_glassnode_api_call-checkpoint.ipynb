# %% [markdown]
# # Glassnode API Call

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
# Insert API key here
API_KEY = '1vXKptlEX84OoMidufyRXLtNDSg'

# %% [markdown]
# Creating a list of endpoints for the features I am interested in.

# %%
urls = ['https://api.glassnode.com/v1/metrics/addresses/count',
'https://api.glassnode.com/v1/metrics/addresses/sending_count',
'https://api.glassnode.com/v1/metrics/addresses/receiving_count',
'https://api.glassnode.com/v1/metrics/addresses/active_count',
'https://api.glassnode.com/v1/metrics/addresses/new_non_zero_count',
'https://api.glassnode.com/v1/metrics/blockchain/block_height',
'https://api.glassnode.com/v1/metrics/indicators/sopr',
'https://api.glassnode.com/v1/metrics/market/price_usd_close',
'https://api.glassnode.com/v1/metrics/market/marketcap_usd',
'https://api.glassnode.com/v1/metrics/mining/difficulty_latest',
'https://api.glassnode.com/v1/metrics/mining/hash_rate_mean']

# %% [markdown]
# ### Feature Descriptions
# |Feature Name|Description|
# |------------|-----------|
# |count|The total number of unique addresses that ever appeared in a transaction of the native coin in the network.|
# |sending_count|The number of unique addresses that were active as a sender of funds. Only addresses that were active as a sender in successful non-zero transfers are counted.|
# |receiving_count|The number of unique addresses that were active as a receiver of funds. Only addresses that were active as a receiver in successful non-zero transfers are counted.|
# |active_count|The number of unique addresses that were active either as a sender or receiver. Only addresses that were active in successful transactions are counted.|
# |new_non_zero_count|The number of unique addresses that appeared for the first time in a transaction of the native coin in the network.|
# |block_height|The block height, i.e. the total number of blocks ever created and included in the main blockchain.|
# |sopr|The Spent Output Profit Ratio (SOPR) is computed by dividing the realized value (in USD) divided by the value at creation (USD) of a spent output. Or simply: price sold / price paid.|
# |price_usd_close|The asset's closing price in USD.|
# |marketcap_usd|The market capitalization (or network value) is defined as the product of the current supply by the current USD price.|
# |difficulty_latest|The current estimated number of hashes required to mine a block. Note: Bitcoin difficulty is often denoted as the relative difficulty with respect to the genesis block, which required approximately 2^32 hashes. For better comparison across blockchains, our values are denoted in raw hashes.|
# |hash_rate_mean|The average estimated number of hashes per second produced by the miners in the network.|

# %%
len(urls)
# Out:
# 11

# %%
data = []
for url in urls:
  label = url.split('/')[-1]
      
  # make API request
  res = requests.get(url, params={'a': 'ETH'
                                  ,'api_key': API_KEY})
  # convert to pandas dataframe
  df = pd.read_json(res.text, convert_dates=['t'])
  df.set_index('t', inplace = True)
  df.rename(columns={'v':label}, inplace=True)
  data.append(df)

# %%
## Inspecting one dataframe from list of results
data
# Out:
# [                count
#  t
#  2015-07-30       9203
#  2015-07-31       9359
#  2015-08-01       9474
#  2015-08-02       9561
#  2015-08-03       9637
#  ...               ...
#  2021-09-09  127707457
#  2021-09-10  127802200
#  2021-09-11  127899284
#  2021-09-12  127999235
#  2021-09-13  128090204
#
#  [2238 rows x 1 columns],
#              sending_count
#  t
#  2015-08-02      1102546374148
#  2015-08-03      1154731637775
#  ...                       ...
#  2021-09-09   9039992063016280
#  2021-09-10   9058536219278930
#  2021-09-11   8871958334513730
#  2021-09-12   9209589988362140
#  2021-09-13   9046425212819710
#
#  [2238 rows x 1 columns],
#              hash_rate_mean
#  t
#  2015-07-30    1.910758e+10
#  2015-07-31    4.679999e+10
#  2015-08-01    5.421432e+10
#  2015-08-02    6.315518e+10
#  2015-08-03    6.876058e+10
#  ...                    ...
#  2021-09-09    6.562142e+14
#  2021-09-10    6.606451e+14
#  2021-09-11    6.606939e+14
#  2021-09-12    6.851246e+14
#  2021-09-13    6.622349e+14
#
#  [2238 rows x 1 columns]]

# %%
# Creating a dataframe from the list of results generated from the API
data_df = pd.concat(data, axis=1)
data_df
# Out:
#                   count  sending_count  receiving_count  active_count  \
# t
# 2015-07-30       9203.0            0.0              0.0           0.0
# 2015-07-31       9359.0            0.0              0.0           0.0
# 2015-08-01       9474.0            0.0              0.0           0.0
# 2015-08-02       9561.0            0.0              0.0           0.0
# 2015-08-03       9637.0            0.0              0.0           0.0
# ...                 ...            ...              ...           ...
# 2021-09-10  127802200.0       252036.0         283405.0      517875.0
# 2021-09-11  127899284.0       323971.0         276903.0      583239.0
# 2021-09-12  127999235.0       278421.0         282523.0      524894.0
# 2021-09-13  128090204.0       339793.0         265046.0      583723.0
# 2021-09-14          NaN            NaN              NaN           NaN
#
#             new_non_zero_count  block_height      sopr  price_usd_close  \
# t
# 2015-07-30              9203.0        6911.0       NaN              NaN
# 2015-07-31               156.0       13774.0       NaN              NaN
# 2015-08-01               115.0       19067.0       NaN              NaN
# 2015-08-02                87.0       24425.0       NaN              NaN
# 2015-08-03                76.0       29705.0       NaN              NaN
# ...                        ...           ...       ...              ...
# 2021-09-10             94743.0    13201142.0  1.014722      3212.099640
# 2021-09-11             97084.0    13207538.0  1.031268      3266.273666
# 2021-09-12             99951.0    13214076.0  1.048310      3410.418612
# 2021-09-13             90969.0    13220488.0  1.021964      3289.677335
# 2021-09-14                 NaN           NaN       NaN      3353.253786
#
#             marketcap_usd  difficulty_latest  hash_rate_mean
# t
# 2015-07-30            NaN       3.382792e+11    1.910758e+10
# 2015-07-31            NaN       8.231927e+11    4.679999e+10
# 2015-08-01            NaN       9.566506e+11    5.421432e+10
# 2015-08-02            NaN       1.102546e+12    6.315518e+10
# 2015-08-03            NaN       1.154732e+12    6.876058e+10
# ...                   ...                ...             ...
# 2021-09-10   3.949930e+11       9.058536e+15    6.606451e+14
# 2021-09-11   3.857475e+11       8.871958e+15    6.606939e+14
# 2021-09-12   3.962536e+11       9.209590e+15    6.851246e+14
# 2021-09-13   3.828427e+11       9.046425e+15    6.622349e+14
# 2021-09-14            NaN                NaN             NaN
#
# [2239 rows x 11 columns]

# %%
# Generating list of columns with more than 1 missing value
test_list = list(data_df.isna().sum()[data_df.isna().sum() > 1].index)
test_list
# Out:
# ['sopr', 'price_usd_close', 'marketcap_usd']

# %%
# Looping through list and comparing index values
for i in test_list:
    display(data_df[data_df[i].isna()].index)
# Out:
# DatetimeIndex(['2015-07-30', '2015-07-31', '2015-08-01', '2015-08-02',
#                '2015-08-03', '2015-08-04', '2015-08-05', '2015-08-06',
#                '2021-09-14'],
#               dtype='datetime64[ns]', name='t', freq=None)
# DatetimeIndex(['2015-07-30', '2015-07-31', '2015-08-01', '2015-08-02',
#                '2015-08-03', '2015-08-04', '2015-08-05', '2015-08-06',
#                '2015-08-07', '2018-04-12', '2018-04-13', '2018-04-14',
#                '2018-04-15'],
#               dtype='datetime64[ns]', name='t', freq=None)
# DatetimeIndex(['2015-07-30', '2015-07-31', '2015-08-01', '2015-08-02',
#                '2015-08-03', '2015-08-04', '2015-08-05', '2015-08-06',
#                '2015-08-07', '2021-09-14'],
#               dtype='datetime64[ns]', name='t', freq=None)

# %%
# Dropping null values
data_df = data_df.dropna(axis=0)#.isna().sum

# %%
data_df
# Out:
#                   count  sending_count  receiving_count  active_count  \
# t
# 2015-08-08      10641.0          582.0            439.0         800.0
# 2015-08-09      10894.0          457.0            489.0         731.0
# 2015-08-10      11543.0          804.0            749.0         997.0
# 2015-08-11      13432.0         2119.0           2106.0        2339.0
# 2015-08-12      13744.0          565.0            673.0         904.0
# ...                 ...            ...              ...           ...
# 2021-09-09  127707457.0       217560.0         290503.0      481475.0
# 2021-09-10  127802200.0       252036.0         283405.0      517875.0
# 2021-09-11  127899284.0       323971.0         276903.0      583239.0
# 2021-09-12  127999235.0       278421.0         282523.0      524894.0
# 2021-09-13  128090204.0       339793.0         265046.0      583723.0
#
#             new_non_zero_count  block_height      sopr  price_usd_close  \
# t
# 2015-08-08               353.0       55869.0  0.459823         0.769981
# 2015-08-09               253.0       60992.0  0.403942         0.719830
# 2015-08-10               649.0       66247.0  0.360587         0.700705
# 2015-08-11              1889.0       71527.0  0.614763         1.088361
# 2015-08-12               312.0       76651.0  0.609176         1.214071
# ...                        ...           ...       ...              ...
# 2021-09-09             93361.0    13194683.0  1.035343      3428.141046
# 2021-09-10             94743.0    13201142.0  1.014722      3212.099640
# 2021-09-11             97084.0    13207538.0  1.031268      3266.273666
# 2021-09-12             99951.0    13214076.0  1.048310      3410.418612
# 2021-09-13             90969.0    13220488.0  1.021964      3289.677335
#
#             marketcap_usd  difficulty_latest  hash_rate_mean
# t
# 2015-08-08   8.983510e+07       1.606016e+12    9.644985e+10
# 2015-08-09   5.507245e+07       1.741399e+12    1.013969e+11
# 2015-08-10   4.878861e+07       1.948102e+12    1.116431e+11
# 2015-08-11   5.745360e+07       2.171897e+12    1.240757e+11
# 2015-08-12   8.079017e+07       2.248238e+12    1.308930e+11
# ...                   ...                ...             ...
# 2021-09-09   4.098615e+11       9.039992e+15    6.562142e+14
# 2021-09-10   3.949930e+11       9.058536e+15    6.606451e+14
# 2021-09-11   3.857475e+11       8.871958e+15    6.606939e+14
# 2021-09-12   3.962536e+11       9.209590e+15    6.851246e+14
# 2021-09-13   3.828427e+11       9.046425e+15    6.622349e+14
#
# [2225 rows x 11 columns]

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2225 entries, 2015-08-08 to 2021-09-13
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   count               2225 non-null   float64
#  1   sending_count       2225 non-null   float64
#  2   receiving_count     2225 non-null   float64
#  3   active_count        2225 non-null   float64
#  4   new_non_zero_count  2225 non-null   float64
#  5   block_height        2225 non-null   float64
#  6   sopr                2225 non-null   float64
#  7   price_usd_close     2225 non-null   float64
#  8   marketcap_usd       2225 non-null   float64
#  9   difficulty_latest   2225 non-null   float64
#  10  hash_rate_mean      2225 non-null   float64
# dtypes: float64(11)
# memory usage: 208.6 KB

# %% [markdown]
# ### EDA

# %%
# Looking at historical closing price
data_df['price_usd_close'].plot(figsize=(16,8), title='ETH Historical Closing Price', ylabel='Price in USD', xlabel='')
plt.rc('font', size=10);

# %%
# Exporting the data set to Excel
data_df.to_excel('data/eth_api_data.xlsx')

# %%
# # Creating a matrix of correlations for each of the features in the dataframe
# corr_matrix = data_df.corr()

# # Creating a boolean mask for all values on or above the matrix diagonal
# corr_matrix_mask = np.triu(np.ones_like(data_df.corr(), dtype=bool));

# %%
# # Creating a heatmap of correlation coefficients
# fig, ax = plt.subplots(figsize=(15,15))
# sns.heatmap(
#             corr_matrix,
#             ax=ax,
#             annot=True,
#             mask=corr_matrix_mask,
#             cbar_kws={"label": "Correlation", "orientation": "horizontal", "pad": .2, "extend": "both"})
# plt.savefig('images/eth_glassnode_correlation_matrix.png');

# %%
# # Looking at how each feature correlates to price since it is our target variable
# plt.figure(figsize=(4,10))
# heatmap = sns.heatmap(data_df.corr()[['price_usd_close']].sort_values(by='price_usd_close', ascending=False), vmin=-1, vmax=1, linewidths=1, linecolor='black', annot=True, fmt='.2g', cmap="gist_heat")
# plt.savefig('images/eth_glassnode_feature_correlation.png');

# %%
# # Creating visualizations for each of our features as they relate to the price of houses sold in our dataset
# x = data_df.drop(['price_usd_close', 'marketcap_usd'], axis=1)
# y= data_df.price_usd_close
# fig, axes = plt.subplots(ncols=3, nrows=3, figsize=(20, 14))
# fig.set_tight_layout(True)
# for index, col in enumerate(x.columns): 
#     ax = axes[index//3][index%3]
#     ax.scatter(x[col], y, alpha=0.2)
#     ax.set_xlabel(col)
#     ax.set_ylabel("ETH price")
#     plt.savefig('images/eth_feature_scatterplots.png');
